# %% [markdown]
# <a href="https://colab.research.google.com/github/codewithswatiee/DS-AI-ML/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ##Series

# %%
data = [1, 2, 3, 4, 5]
series = pd.Series(data)
print(series)
print("Type: ", type(series))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# Type:  <class 'pandas.core.series.Series'>

# %%
## Create a series from dictionary
data = {'a': 1, 'b': 2, 'c': 3}
series = pd.Series(data)
print(series)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data=[10, 20, 30]
index=['a', 'b', 'c']
series = pd.Series(data, index=index)
print(series)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# ## DataFrame

# %%
#creation of dataFrame from dictionary
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'San Francisco', 'Los Angeles']
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles

# %%
## creation of df from a list of dictionaries
data = [
    {'Name': 'Alice', 'Age': 25, 'City': 'New York'},
    {'Name': 'Bob', 'Age': 30, 'City': 'San Francisco'},
    {'Name': 'Charlie', 'Age': 35, 'City': 'Los Angeles'}
]

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles

# %%
## Reading from csv
df = pd.read_csv('/content/diabetes (1).csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
## Accessing data drom df
df
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles

# %%
df['Name']
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: object

# %%
df.loc[0]
# Out:
# Name       Alice
# Age           25
# City    New York
# Name: 0, dtype: object

# %%
df.iloc[0][2]
# Out:
# <ipython-input-18-2403250610>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[0][2]
# 'New York'

# %%
## Accessing a specified element

df.at[1, 'Age']
# Out:
# np.int64(30)

# %%
## Accessing a specified element using iat
df.iat[2, 0]
# Out:
# 'Charlie'

# %%
## dropping row
df.drop(1, inplace=True)
df
# Out:
#       Name  Age         City  Salary
# 0    Alice   26     New York   10000
# 2  Charlie   36  Los Angeles  456700

# %%
## statistical summary

df.describe()
# Out:
#              Age         Salary
# count   2.000000       2.000000
# mean   31.000000  233350.000000
# std     7.071068  315864.599156
# min    26.000000   10000.000000
# 25%    28.500000  121675.000000
# 50%    31.000000  233350.000000
# 75%    33.500000  345025.000000
# max    36.000000  456700.000000
